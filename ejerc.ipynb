# %%
from search import Problem

# %%
class ControlContenedores(Problem):
    """Problema de ControlContenedores:
    Representaremos los estados como tupla de tuplas (x,y,z) de un string x 'M1' o 'M2' que indica la malla 1 o la malla 2 ,
    y un int 1, 2, 3 de la posicion en cada malla de izquierda a derecha y z una tupla de los contenedores puesto uno
    encima del otro de izquierda a derecha y 0 indica que es vacia"""

    def __init__(self):
        self.initial = (('M1',1,[1,7,0]),('M1',2,[9,10,0]),('M1',3,[11,0,0]),('M2',1,[4,8,0]),('M2',2,[5,3,2]),('M2',3,[6,0,0]))
    
    def actions(self,estado):
        Muella_1_p1 = estado[0][2]
        Muella_1_p2 = estado[1][2]
        Muella_1_p3 = estado[2][2]
        Muella_2_p1 = estado[3][2]
        Muella_2_p2 = estado[4][2]
        Muella_2_p3 = estado[5][2]
        accs = list()
        
        ###dentro del muella 01
        if(Muella_1_p1!=[0,0,0] and 0 in Muella_1_p2):
            accs.append("apilar un contenedor del Muella_1_p1 al Muella_1_p2")
        if(Muella_1_p1!=[0,0,0] and 0 in Muella_1_p3):
            accs.append("apilar un contenedor del Muella_1_p1 al Muella_1_p3")
        if(Muella_1_p2!=[0,0,0] and 0 in Muella_1_p1):
            accs.append("apilar un contenedor del Muella_1_p2 al Muella_1_p1")
        if(Muella_1_p2!=[0,0,0] and 0 in Muella_1_p3):
            accs.append("apilar un contenedor del Muella_1_p2 al Muella_1_p3")
        if(Muella_1_p3!=[0,0,0] and 0 in Muella_1_p1):
            accs.append("apilar un contenedor del Muella_1_p3 al Muella_1_p1")
        if(Muella_1_p3!=[0,0,0] and 0 in Muella_1_p2):
            accs.append("apilar un contenedor del Muella_1_p3 al Muella_1_p2")
            
         ###dentro del muella 02
        if(Muella_2_p1!=[0,0,0] and 0 in Muella_2_p2):
            accs.append("apilar un contenedor del Muella_2_p1 al Muella_2_p2")
        if(Muella_2_p1!=[0,0,0] and 0 in Muella_2_p3):
            accs.append("apilar un contenedor del Muella_2_p1 al Muella_2_p3")
        if(Muella_2_p2!=[0,0,0] and 0 in Muella_2_p1):
            accs.append("apilar un contenedor del Muella_2_p2 al Muella_2_p1")
        if(Muella_2_p2!=[0,0,0] and 0 in Muella_2_p3):
            accs.append("apilar un contenedor del Muella_2_p2 al Muella_2_p3")
        if(Muella_2_p3!=[0,0,0] and 0 in Muella_2_p1):
            accs.append("apilar un contenedor del Muella_2_p3 al Muella_2_p1")
        if(Muella_2_p3!=[0,0,0] and 0 in Muella_2_p2):
            accs.append("apilar un contenedor del Muella_2_p3 al Muella_2_p2")
            
        
        ###de muella 01 a la muella 02
        if(Muella_1_p1!=[0,0,0] and 0 in Muella_2_p1):
            accs.append("apilar un contenedor del Muella_1_p1 al Muella_2_p1")
        if(Muella_1_p1!=[0,0,0] and 0 in Muella_2_p2):
            accs.append("apilar un contenedor del Muella_1_p1 al Muella_2_p2")
        if(Muella_1_p1!=[0,0,0] and 0 in Muella_2_p3):
            accs.append("apilar un contenedor del Muella_1_p1 al Muella_2_p3")
            
        if(Muella_1_p2!=[0,0,0] and 0 in Muella_2_p1):
            accs.append("apilar un contenedor del Muella_1_p2 al Muella_2_p1")
        if(Muella_1_p2!=[0,0,0] and 0 in Muella_2_p2):
            accs.append("apilar un contenedor del Muella_1_p2 al Muella_2_p2")
        if(Muella_1_p2!=[0,0,0] and 0 in Muella_2_p3):
            accs.append("apilar un contenedor del Muella_1_p2 al Muella_2_p3")
            
        if(Muella_1_p3!=[0,0,0] and 0 in Muella_2_p1):
            accs.append("apilar un contenedor del Muella_1_p3 al Muella_2_p1")
        if(Muella_1_p3!=[0,0,0] and 0 in Muella_2_p2):
            accs.append("apilar un contenedor del Muella_1_p3 al Muella_2_p2")
        if(Muella_1_p3!=[0,0,0] and 0 in Muella_2_p3):
            accs.append("apilar un contenedor del Muella_1_p3 al Muella_2_p3")
            
        
             ###de muella 02 a la muella 01
        if(Muella_2_p1!=[0,0,0] and 0 in Muella_1_p1):
            accs.append("apilar un contenedor del Muella_2_p1 al Muella_1_p1")
        if(Muella_2_p1!=[0,0,0] and 0 in Muella_1_p2):
            accs.append("apilar un contenedor del Muella_2_p1 al Muella_1_p2")
        if(Muella_2_p1!=[0,0,0] and 0 in Muella_1_p3):
            accs.append("apilar un contenedor del Muella_2_p1 al Muella_1_p3")
            
        if(Muella_2_p2!=[0,0,0] and 0 in Muella_1_p1):
            accs.append("apilar un contenedor del Muella_2_p2 al Muella_1_p1")
        if(Muella_2_p2!=[0,0,0] and 0 in Muella_1_p2):
            accs.append("apilar un contenedor del Muella_2_p2 al Muella_1_p2")
        if(Muella_2_p2!=[0,0,0] and 0 in Muella_1_p3):
            accs.append("apilar un contenedor del Muella_2_p2 al Muella_1_p3")
            
        if(Muella_2_p3!=[0,0,0] and 0 in Muella_1_p1):
            accs.append("apilar un contenedor del Muella_2_p3 al Muella_1_p1")
        if(Muella_2_p3!=[0,0,0] and 0 in Muella_1_p2):
            accs.append("apilar un contenedor del Muella_2_p3 al Muella_1_p2")
        if(Muella_2_p3!=[0,0,0] and 0 in Muella_1_p3):
            accs.append("apilar un contenedor del Muella_2_p3 al Muella_1_p3")
            
        return accs
        # se devuelve en accs todas las acciones aplicables
    
    def result(self,estado,accion):
    # aplica una acción a un estado
        NuevoEstado = estado
        ###dentro del muella 01
        if accion == "apilar un contenedor del Muella_1_p1 al Muella_1_p2":
            ###en origen
            indexOrigen = NuevoEstado[0][2].index(0)-1
            elemOrigen = NuevoEstado[0][2][indexOrigen]
            NuevoEstado[0][2][indexOrigen]=0
            ###en destino
            indexdest = NuevoEstado[1][2].index(0)
            NuevoEstado[1][2][indexdest]=elemOrigen
        if accion == "apilar un contenedor del Muella_1_p1 al Muella_1_p3":
            ###en origen
            indexOrigen = NuevoEstado[0][2].index(0)-1
            elemOrigen = NuevoEstado[0][2][indexOrigen]
            NuevoEstado[0][2][indexOrigen]=0
            ###en destino
            indexdest = NuevoEstado[2][2].index(0)
            NuevoEstado[2][2][indexdest]=elemOrigen
        if accion == "apilar un contenedor del Muella_1_p2 al Muella_1_p1":
            ###en origen
            indexOrigen = NuevoEstado[1][2].index(0)-1
            elemOrigen = NuevoEstado[1][2][indexOrigen]
            NuevoEstado[1][2][indexOrigen]=0
            ###en destino
            indexdest = NuevoEstado[0][2].index(0)
            NuevoEstado[0][2][indexdest]=elemOrigen
        if accion == "apilar un contenedor del Muella_1_p2 al Muella_1_p3":
            ###en origen
            indexOrigen = NuevoEstado[1][2].index(0)-1
            elemOrigen = NuevoEstado[1][2][indexOrigen]
            NuevoEstado[1][2][indexOrigen]=0
            ###en destino
            indexdest = NuevoEstado[2][2].index(0)
            NuevoEstado[2][2][indexdest]=elemOrigen
        if accion == "apilar un contenedor del Muella_1_p3 al Muella_1_p1":
            ###en origen
            indexOrigen = NuevoEstado[2][2].index(0)-1
            elemOrigen = NuevoEstado[2][2][indexOrigen]
            NuevoEstado[2][2][indexOrigen]=0
            ###en destino
            indexdest = NuevoEstado[0][2].index(0)
            NuevoEstado[0][2][indexdest]=elemOrigen
        if accion == "apilar un contenedor del Muella_1_p3 al Muella_1_p2":
            ###en origen
            indexOrigen = NuevoEstado[2][2].index(0)-1
            elemOrigen = NuevoEstado[2][2][indexOrigen]
            NuevoEstado[2][2][indexOrigen]=0
            ###en destino
            indexdest = NuevoEstado[1][2].index(0)
            NuevoEstado[1][2][indexdest]=elemOrigen
            
            
            
         ###dentro del muella 02
        if accion == "apilar un contenedor del Muella_2_p1 al Muella_2_p2":
            ###en origen
            indexOrigen = NuevoEstado[3][2].index(0)-1
            elemOrigen = NuevoEstado[3][2][indexOrigen]
            NuevoEstado[3][2][indexOrigen]=0
            ###en destino
            indexdest = NuevoEstado[4][2].index(0)
            NuevoEstado[4][2][indexdest]=elemOrigen
        if accion == "apilar un contenedor del Muella_2_p1 al Muella_2_p3":
            ###en origen
            indexOrigen = NuevoEstado[3][2].index(0)-1
            elemOrigen = NuevoEstado[3][2][indexOrigen]
            NuevoEstado[3][2][indexOrigen]=0
            ###en destino
            indexdest = NuevoEstado[5][2].index(0)
            NuevoEstado[5][2][indexdest]=elemOrigen
        if accion == "apilar un contenedor del Muella_2_p2 al Muella_2_p1":
            ###en origen
            indexOrigen = NuevoEstado[4][2].index(0)-1
            elemOrigen = NuevoEstado[4][2][indexOrigen]
            NuevoEstado[4][2][indexOrigen]=0
            ###en destino
            indexdest = NuevoEstado[3][2].index(0)
            NuevoEstado[3][2][indexdest]=elemOrigen
        if accion == "apilar un contenedor del Muella_2_p2 al Muella_2_p3":
            ###en origen
            indexOrigen = NuevoEstado[4][2].index(0)-1
            elemOrigen = NuevoEstado[4][2][indexOrigen]
            NuevoEstado[4][2][indexOrigen]=0
            ###en destino
            indexdest = NuevoEstado[5][2].index(0)
            NuevoEstado[5][2][indexdest]=elemOrigen
        if accion == "apilar un contenedor del Muella_2_p3 al Muella_2_p1":
            ###en origen
            indexOrigen = NuevoEstado[5][2].index(0)-1
            elemOrigen = NuevoEstado[5][2][indexOrigen]
            NuevoEstado[5][2][indexOrigen]=0
            ###en destino
            indexdest = NuevoEstado[3][2].index(0)
            NuevoEstado[3][2][indexdest]=elemOrigen
        if accion == "apilar un contenedor del Muella_2_p3 al Muella_2_p2":
            ###en origen
            indexOrigen = NuevoEstado[5][2].index(0)-1
            elemOrigen = NuevoEstado[5][2][indexOrigen]
            NuevoEstado[5][2][indexOrigen]=0
            ###en destino
            indexdest = NuevoEstado[4][2].index(0)
            NuevoEstado[4][2][indexdest]=elemOrigen
        
        
        
        
        ###de muella 01 a la muella 02
        
        if accion == "apilar un contenedor del Muella_1_p1 al Muella_2_p1":
            ###en origen
            indexOrigen = NuevoEstado[0][2].index(0)-1
            elemOrigen = NuevoEstado[0][2][indexOrigen]
            NuevoEstado[0][2][indexOrigen]=0
            ###en destino
            indexdest = NuevoEstado[3][2].index(0)
            NuevoEstado[3][2][indexdest]=elemOrigen
        if accion == "apilar un contenedor del Muella_1_p1 al Muella_2_p2":
            ###en origen
            indexOrigen = NuevoEstado[0][2].index(0)-1
            elemOrigen = NuevoEstado[0][2][indexOrigen]
            NuevoEstado[0][2][indexOrigen]=0
            ###en destino
            indexdest = NuevoEstado[4][2].index(0)
            NuevoEstado[4][2][indexdest]=elemOrigen
        if accion == "apilar un contenedor del Muella_1_p1 al Muella_2_p3":
            ###en origen
            indexOrigen = NuevoEstado[0][2].index(0)-1
            elemOrigen = NuevoEstado[0][2][indexOrigen]
            NuevoEstado[0][2][indexOrigen]=0
            ###en destino
            indexdest = NuevoEstado[5][2].index(0)
            NuevoEstado[5][2][indexdest]=elemOrigen
            
        if accion == "apilar un contenedor del Muella_1_p2 al Muella_2_p1":
            ###en origen
            indexOrigen = NuevoEstado[1][2].index(0)-1
            elemOrigen = NuevoEstado[1][2][indexOrigen]
            NuevoEstado[1][2][indexOrigen]=0
            ###en destino
            indexdest = NuevoEstado[3][2].index(0)
            NuevoEstado[3][2][indexdest]=elemOrigen
        if accion == "apilar un contenedor del Muella_1_p2 al Muella_2_p2":
            ###en origen
            indexOrigen = NuevoEstado[1][2].index(0)-1
            elemOrigen = NuevoEstado[1][2][indexOrigen]
            NuevoEstado[1][2][indexOrigen]=0
            ###en destino
            indexdest = NuevoEstado[4][2].index(0)
            NuevoEstado[4][2][indexdest]=elemOrigen
        if accion == "apilar un contenedor del Muella_1_p2 al Muella_2_p3":
            ###en origen
            indexOrigen = NuevoEstado[1][2].index(0)-1
            elemOrigen = NuevoEstado[1][2][indexOrigen]
            NuevoEstado[1][2][indexOrigen]=0
            ###en destino
            indexdest = NuevoEstado[5][2].index(0)
            NuevoEstado[5][2][indexdest]=elemOrigen
            
        if accion == "apilar un contenedor del Muella_1_p3 al Muella_2_p1":
            ###en origen
            indexOrigen = NuevoEstado[2][2].index(0)-1
            elemOrigen = NuevoEstado[2][2][indexOrigen]
            NuevoEstado[2][2][indexOrigen]=0
            ###en destino
            indexdest = NuevoEstado[3][2].index(0)
            NuevoEstado[3][2][indexdest]=elemOrigen
        if accion == "apilar un contenedor del Muella_1_p3 al Muella_2_p2":
            ###en origen
            indexOrigen = NuevoEstado[2][2].index(0)-1
            elemOrigen = NuevoEstado[2][2][indexOrigen]
            NuevoEstado[2][2][indexOrigen]=0
            ###en destino
            indexdest = NuevoEstado[4][2].index(0)
            NuevoEstado[4][2][indexdest]=elemOrigen
        if accion == "apilar un contenedor del Muella_1_p3 al Muella_2_p3":
            ###en origen
            indexOrigen = NuevoEstado[2][2].index(0)-1
            elemOrigen = NuevoEstado[2][2][indexOrigen]
            NuevoEstado[2][2][indexOrigen]=0
            ###en destino
            indexdest = NuevoEstado[5][2].index(0)
            NuevoEstado[5][2][indexdest]=elemOrigen
            
            
        ###de muella 02 a la muella 01
        
        if accion == "apilar un contenedor del Muella_2_p1 al Muella_1_p1":
            ###en origen
            indexOrigen = NuevoEstado[3][2].index(0)-1
            elemOrigen = NuevoEstado[3][2][indexOrigen]
            NuevoEstado[3][2][indexOrigen]=0
            ###en destino
            indexdest = NuevoEstado[0][2].index(0)
            NuevoEstado[0][2][indexdest]=elemOrigen
        if accion == "apilar un contenedor del Muella_2_p1 al Muella_1_p2":
            ###en origen
            indexOrigen = NuevoEstado[3][2].index(0)-1
            elemOrigen = NuevoEstado[3][2][indexOrigen]
            NuevoEstado[3][2][indexOrigen]=0
            ###en destino
            indexdest = NuevoEstado[1][2].index(0)
            NuevoEstado[1][2][indexdest]=elemOrigen
        if accion == "apilar un contenedor del Muella_2_p1 al Muella_1_p3":
            ###en origen
            indexOrigen = NuevoEstado[3][2].index(0)-1
            elemOrigen = NuevoEstado[3][2][indexOrigen]
            NuevoEstado[3][2][indexOrigen]=0
            ###en destino
            indexdest = NuevoEstado[2][2].index(0)
            NuevoEstado[2][2][indexdest]=elemOrigen
            
        if accion == "apilar un contenedor del Muella_2_p2 al Muella_1_p1":
            ###en origen
            indexOrigen = NuevoEstado[4][2].index(0)-1
            elemOrigen = NuevoEstado[4][2][indexOrigen]
            NuevoEstado[4][2][indexOrigen]=0
            ###en destino
            indexdest = NuevoEstado[0][2].index(0)
            NuevoEstado[0][2][indexdest]=elemOrigen
        if accion == "apilar un contenedor del Muella_2_p2 al Muella_1_p2":
            ###en origen
            indexOrigen = NuevoEstado[4][2].index(0)-1
            elemOrigen = NuevoEstado[4][2][indexOrigen]
            NuevoEstado[4][2][indexOrigen]=0
            ###en destino
            indexdest = NuevoEstado[1][2].index(0)
            NuevoEstado[1][2][indexdest]=elemOrigen
        if accion == "apilar un contenedor del Muella_2_p2 al Muella_1_p3":
            ###en origen
            indexOrigen = NuevoEstado[4][2].index(0)-1
            elemOrigen = NuevoEstado[4][2][indexOrigen]
            NuevoEstado[4][2][indexOrigen]=0
            ###en destino
            indexdest = NuevoEstado[2][2].index(0)
            NuevoEstado[2][2][indexdest]=elemOrigen
            
        if accion == "apilar un contenedor del Muella_2_p3 al Muella_1_p1":
            ###en origen
            indexOrigen = NuevoEstado[5][2].index(0)-1
            elemOrigen = NuevoEstado[5][2][indexOrigen]
            NuevoEstado[5][2][indexOrigen]=0
            ###en destino
            indexdest = NuevoEstado[0][2].index(0)
            NuevoEstado[0][2][indexdest]=elemOrigen
        if accion == "apilar un contenedor del Muella_2_p3 al Muella_1_p2":
            ###en origen
            indexOrigen = NuevoEstado[5][2].index(0)-1
            elemOrigen = NuevoEstado[5][2][indexOrigen]
            NuevoEstado[5][2][indexOrigen]=0
            ###en destino
            indexdest = NuevoEstado[1][2].index(0)
            NuevoEstado[1][2][indexdest]=elemOrigen
        if accion == "apilar un contenedor del Muella_2_p3 al Muella_1_p3":
            ###en origen
            indexOrigen = NuevoEstado[5][2].index(0)-1
            elemOrigen = NuevoEstado[5][2][indexOrigen]
            NuevoEstado[5][2][indexOrigen]=0
            ###en destino
            indexdest = NuevoEstado[2][2].index(0)
            NuevoEstado[2][2][indexdest]=elemOrigen      
        return NuevoEstado
    
    def goal_test(self,estado):
        ### primera condicion que todos los contenedores objetivos tienen que estar en la muella01
            ContenedoresObjetivos  = [7, 4, 3]
            ContenedoresMuelle1=[estado[0][2],estado[1][2],estado[2][2]]
            for objetivo in ContenedoresObjetivos:
                if objetivo not in ContenedoresMuelle1[0] and objetivo not in ContenedoresMuelle1[1] and objetivo not in ContenedoresMuelle1[2]:
                    return False
            return True

# %%
p=ControlContenedores()
p.initial
# Out:
# (('M1', 1, [1, 7, 0]),
#  ('M1', 2, [9, 10, 0]),
#  ('M1', 3, [11, 0, 0]),
#  ('M2', 1, [4, 8, 0]),
#  ('M2', 2, [5, 3, 2]),
#  ('M2', 3, [6, 0, 0]))

# %%
p.actions(p.initial)
# Out:
# ['apilar un contenedor del Muella_1_p1 al Muella_1_p2',
#  'apilar un contenedor del Muella_1_p1 al Muella_1_p3',
#  'apilar un contenedor del Muella_1_p2 al Muella_1_p1',
#  'apilar un contenedor del Muella_1_p2 al Muella_1_p3',
#  'apilar un contenedor del Muella_1_p3 al Muella_1_p1',
#  'apilar un contenedor del Muella_1_p3 al Muella_1_p2',
#  'apilar un contenedor del Muella_2_p1 al Muella_2_p3',
#  'apilar un contenedor del Muella_2_p2 al Muella_2_p1',
#  'apilar un contenedor del Muella_2_p2 al Muella_2_p3',
#  'apilar un contenedor del Muella_2_p3 al Muella_2_p1',
#  'apilar un contenedor del Muella_1_p1 al Muella_2_p1',
#  'apilar un contenedor del Muella_1_p1 al Muella_2_p3',
#  'apilar un contenedor del Muella_1_p2 al Muella_2_p1',
#  'apilar un contenedor del Muella_1_p2 al Muella_2_p3',
#  'apilar un contenedor del Muella_1_p3 al Muella_2_p1',
#  'apilar un contenedor del Muella_1_p3 al Muella_2_p3',
#  'apilar un contenedor del Muella_2_p1 al Muella_1_p1',
# ...

# %%
p.result(p.initial, "apilar un contenedor del Muella_1_p1 al Muella_2_p1")
# Out:
# (('M1', 1, [1, 0, 0]),
#  ('M1', 2, [9, 10, 0]),
#  ('M1', 3, [11, 0, 0]),
#  ('M2', 1, [4, 8, 7]),
#  ('M2', 2, [5, 3, 2]),
#  ('M2', 3, [6, 0, 0]))

# %%
# Out:
# True

# %%
p.goal_test(p.initial)
# Out:
# False

# %%
from search import *
from search import breadth_first_tree_search, depth_first_tree_search, depth_first_graph_search, breadth_first_graph_search

# %%
breadth_first_graph_search(ControlContenedores()).solution()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [117], in <cell line: 1>()
# ----> 1 breadth_first_graph_search(ControlContenedores()).solution()
#
# File ~\Desktop\IA1\search.py:251, in breadth_first_graph_search(problem)
#     249 while frontier:
#     250     node = frontier.popleft()
# --> 251     explored.add(node.state)
#     252     for child in node.expand(problem):
#     253         if child.state not in explored and child not in frontier:
#
# TypeError: unhashable type: 'list'
